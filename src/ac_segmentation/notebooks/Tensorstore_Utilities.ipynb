# %%
from ac_segmentation.utils.tensorstore import create_tensor, open_tensor, zarr_to_precomputed, AWS_Parameters
from ac_segmentation.utils.zarr_to_CATMAID import zarr_to_CATMAID_project
import numpy as np

# %% [markdown]
# **Parameter Key:** <br>
# store = the type of data store, including: memory, file, s3   <br>
# driver = the type of file object, including: zarr, n5, neuroglancer_precomputed<br>
# dtype = datatype of numpy array <br>
# fill_value = value to fill array element with <br>
# arr = numpy array, if applicable<br>
# chunk_shape = file array size for chunked file format (EX: [64,64,64]) <br>
# res = resolution of dimensions, if not isotropic (EX: [.7,.7,.8])<br>
# scale, scales = MIP scale<br>
# AWS Key, Secret Key = AWS credentials

# %% [markdown]
# **Set AWS key credentials and create a parameter object if importing from or exporting to S3 bucket**

# %%
AWS_Key="AKIAVPGF7MJCX4GNVEX7"
AWS_Secret_Key="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"

AWS_param = AWS_Parameters(region='us-west-2', profile=None, endpoint_url=None)
AWS_param.add_credentials(AWS_Key,AWS_Secret_Key)

# %% [markdown]
# **Create a tensor object**

# %%
#neuroglancer_precomputed driver requires a 4d arr_shape
arr = create_tensor('ac-catmaid-dev/Data/Test.zarr/', arr_shape=[100,100,100], store='s3', driver='zarr', 
                    dtype='float32', fill_value=-np.inf, AWS_param=AWS_param)

# %% [markdown]
# **Open a file as a tensor object**

# %%
#data types: zarr, n5, precomputed
arr = open_tensor('ac-catmaid-dev/Data/Test.zarr/', driver='zarr', store='s3', AWS_param=AWS_param)

# %% [markdown]
# **Convert zarr file to precomputed file**

# %%
zarr_to_precomputed(zarr_path='/ACdata/Users/kevin/ispim_ome_zarr/H17_x55_S32_230412_highres/H17_x55_S32_230412_highres.zarr/highres_Pos54/', 
                    out_path=" ", store='file', chunks=(64,64,64), cutout=[23000,27000,0,576,0,576], 
                    scales=6, AWS_param=AWS_param)

# %% [markdown]
# **Create CATMAID project from zarr file**

# %%
#container_id refers to the docker image id
stack = zarr_to_CATMAID_project(zarr_path="/ACdata/Users/kevin/ispim_ome_zarr/H17_x55_S39a_230808_highres/H17_x55_S39a_230808_highres.zarr/highres_Pos52/", 
                                out_path="ac-catmaid-dev/Data/Test_pre.zarr/", container_id="", cutout=[23000,27000,0,576,0,576], 
                                project='TestProject', stack='TestStack', AWS_param=AWS_param, translation=(0,0,0))
